# %% [markdown]
# ## 데이터셋 다운로드

# %%
# !git clone https://github.com/smartboy110/denoising-datasets.git
# Out:
# fatal: destination path 'denoising-datasets' already exists and is not an empty directory.

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /opt/anaconda3/envs/STEP1/lib/python3.10/site-packages (1.8.0)

# %% [markdown]
# **DnCNN-S** : 알려진 특정 노이즈 레벨(15,25,50)을 가진 가우시안 노이즈 제거를 위한 모델 <br> patch_size=40 <br>
# **DnCNN-B**: 블라인드 가우시안 노이즈(0~55) 제거를 위한 모델 <br> patch_size=50 <br>
# **DnCNN-C**: 블라인드 가우시안 노이즈(0~55) 제거를 위한 모델 - COLOR <br> patch_size=50 <br>
# **CDnCNNB** : 블라인드 컬러 노이즈 제거 모델 <br> patch_size=50<br>

# %%
import os
import copy
import time
import torch
import random
import numpy as np
from PIL import Image
from torchinfo import summary

import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torchvision.transforms import functional as F

# %%
class Config:
  #Path
  train_data_root = "denoising-datasets/BSD500/train"
  val_data_root = "denoising-datasets/BSD500/val"

  # Dataset
  patch_size = 50
  train_ratio=0.9
  patches_per_image = 200
  # DnCNN-C 노이즈
  sigma_range=(0,55)

  #Model
  num_layers=20
  in_channels=3
  out_channels=64
  kernel_size=3

  #Training
  batch_size=128
  num_epochs=50
  learning_rate=1e-3

config = Config()

# %% [markdown]
# ## Data Loading & Preprocessing

# %%
class DnCNN_Dataset(Dataset):
  def __init__(self, root, file_list, patch_size, sigma_range, patches_per_image=1000, is_train=True):
    self.root = root
    self.file_list = file_list
    self.patch_size = patch_size
    self.is_train = is_train
    # sigma
    self.sigma_min = sigma_range[0] / 255.0  # 0 / 255 = 0
    self.sigma_max = sigma_range[1] / 255.0  # 55 / 255 = 0.216
    self.patches_per_image = patches_per_image if is_train else 1

    if not is_train:
            self.fixed_data = []
            for idx in range(len(file_list)):
                img = Image.open(os.path.join(root, file_list[idx])).convert('RGB')
                img = np.array(img, dtype=np.float32) / 255.0
                h, w = img.shape[:2]
                top = random.randint(0, h - patch_size)
                left = random.randint(0, w - patch_size)
                patch = img[top:top+patch_size, left:left+patch_size]
                clean = torch.from_numpy(patch).permute(2, 0, 1)
                sigma = random.uniform(self.sigma_min, self.sigma_max)
                noise = torch.randn_like(clean) * sigma
                noisy = clean + noise
                self.fixed_data.append((noisy, clean))

  def __len__(self):
    return len(self.file_list)*self.patches_per_image

  def __getitem__(self, index):
    if not self.is_train:
            return self.fixed_data[index]
    img_idx = index % len(self.file_list)
    img = Image.open(os.path.join(self.root, self.file_list[img_idx])).convert('RGB')
    img = np.array(img, dtype=np.float32)/255.0

    h,w = img.shape[:2]
    top = random.randint(0, h-self.patch_size)
    left = random.randint(0, w-self.patch_size)

    patch = img[top:top+self.patch_size, left:left+self.patch_size]
    #Random Rotation + randomfilp 적용
    k = random.randint(0,3)
    patch = np.rot90(patch, k).copy()
    if random.random() >0.5:
        patch = np.fliplr(patch).copy() 
      
    # Tensor 변환
    clean = torch.from_numpy(patch).permute(2, 0, 1)

    # Gaussian noise 추가
    sigma = random.uniform(self.sigma_min, self.sigma_max)  # 0 ~ 0.216
    noise = torch.randn_like(clean) * sigma
    noisy = clean + noise

    return noisy, clean

# %%
# 이미지 파일만 필터링
def get_image_files(directory):
    """
    디렉토리에서 이미지 파일만 필터링
    """
    valid_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff'}
    all_files = os.listdir(directory)
    image_files = [f for f in all_files
                   if os.path.splitext(f)[1].lower() in valid_extensions]
    return sorted(image_files)

train_files = get_image_files(config.train_data_root)
val_files = get_image_files(config.val_data_root)
total = len(train_files) + len(val_files)

train_list = train_files[:]
val_list = val_files[:]

print(f'Total: {total}')
print(f'Train: {len(train_list)}')
print(f'Val:   {len(val_list)}')
#print(f'Test:  {len(test_list)}')
# Out:
# Total: 432
# Train: 400
# Val:   32

# %%
train_dataset_vis = DnCNN_Dataset(
    root=config.train_data_root,
    file_list=train_list,
    patch_size=config.patch_size,
    sigma_range=config.sigma_range,
    patches_per_image=config.patches_per_image,
    is_train=True
)

def visualize_samples_debug(dataset, num_samples=5):
    fig, axes = plt.subplots(num_samples, 3, figsize=(15, num_samples*2.5))

    if num_samples == 1:
        axes = axes.reshape(1, -1)

    for i in range(num_samples):
        noisy, clean = dataset[i]

        # [3, H, W] -> [H, W, 3]
        noisy_np = noisy.permute(1, 2, 0).numpy()
        clean_np = clean.permute(1, 2, 0).numpy()
        noise_np = (noisy - clean).permute(1, 2, 0).numpy()

        # 통계 정보
        print(f'Sample {i+1}:')
        print(f'  Clean range: [{clean_np.min():.3f}, {clean_np.max():.3f}]')
        print(f'  Noisy range: [{noisy_np.min():.3f}, {noisy_np.max():.3f}]')
        print(f'  Noise std: {noise_np.std():.4f} ({noise_np.std()*255:.2f}/255)')

        # Clip to [0, 1] for visualization
        noisy_display = np.clip(noisy_np, 0, 1)
        clean_display = np.clip(clean_np, 0, 1)

        # Clean 이미지
        axes[i, 0].imshow(clean_display)
        axes[i, 0].set_title(f'Clean {i+1}')
        axes[i, 0].axis('off')

        # Noisy 이미지
        axes[i, 1].imshow(noisy_display)
        axes[i, 1].set_title(f'Noisy {i+1}')
        axes[i, 1].axis('off')

        # Noise만 (시각화용)
        noise_display = noise_np - noise_np.min()
        noise_display = noise_display / (noise_display.max() + 1e-8)
        axes[i, 2].imshow(noise_display)
        axes[i, 2].set_title(f'Noise {i+1}')
        axes[i, 2].axis('off')

    plt.tight_layout()
    plt.show()


# 샘플 시각화
print('\n' + '='*70)
print('Sample Visualization: Noisy vs Clean')
print('='*70)
visualize_samples_debug(train_dataset_vis, num_samples=5)
# Out:
# ======================================================================
# Sample Visualization: Noisy vs Clean
# ======================================================================
# Sample 1:
#   Clean range: [0.141, 0.914]
#   Noisy range: [-0.337, 1.360]
#   Noise std: 0.1692 (43.15/255)
# Sample 2:
#   Clean range: [0.094, 1.000]
#   Noisy range: [-0.502, 1.347]
#   Noise std: 0.1722 (43.91/255)
# Sample 3:
#   Clean range: [0.157, 0.961]
#   Noisy range: [0.157, 0.961]
#   Noise std: 0.0009 (0.23/255)
# Sample 4:
#   Clean range: [0.357, 0.635]
#   Noisy range: [-0.347, 1.222]
#   Noise std: 0.1999 (50.96/255)
# Sample 5:
#   Clean range: [0.157, 1.000]
#   Noisy range: [0.139, 1.063]
#   Noise std: 0.0181 (4.62/255)

# %%
def check_noise_levels(dataset, num_samples=10):
    """
    여러 샘플의 노이즈 레벨과 PSNR 확인
    """
    print('\n' + '='*70)
    print('Noise Level Check')

    for i in range(num_samples):
        noisy, clean = dataset[i]

        # MSE 계산
        mse = torch.mean((noisy - clean) ** 2).item()
        psnr = 10 * np.log10(1.0 / mse) if mse > 0 else float('inf')

        # 노이즈 강도 (std)
        noise = noisy - clean
        noise_std = torch.std(noise).item() * 255  # [0, 255] 스케일로 변환

        print(f'Sample {i+1}: Noise σ ≈ {noise_std:.2f}, PSNR: {psnr:.2f} dB')

check_noise_levels(train_dataset_vis, num_samples=10)
# Out:
# ======================================================================
# Noise Level Check
# Sample 1: Noise σ ≈ 54.96, PSNR: 13.33 dB
# Sample 2: Noise σ ≈ 37.22, PSNR: 16.72 dB
# Sample 3: Noise σ ≈ 15.93, PSNR: 24.09 dB
# Sample 4: Noise σ ≈ 38.40, PSNR: 16.44 dB
# Sample 5: Noise σ ≈ 33.85, PSNR: 17.54 dB
# Sample 6: Noise σ ≈ 15.96, PSNR: 24.07 dB
# Sample 7: Noise σ ≈ 8.62, PSNR: 29.42 dB
# Sample 8: Noise σ ≈ 29.97, PSNR: 18.60 dB
# Sample 9: Noise σ ≈ 39.31, PSNR: 16.24 dB
# Sample 10: Noise σ ≈ 13.48, PSNR: 25.54 dB

# %% [markdown]
# ## Model Architecture

# %%
class DnCNN(nn.Module):
  def __init__(self, in_channels, out_channels, depth, kernel_size):
    super(DnCNN, self).__init__()

    layers =[]
    padding = kernel_size // 2

    # First Layer
    layers.append(nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=padding))
    layers.append(nn.ReLU(inplace=True))

    # Mid Layer
    for _ in range(depth-2):
      layers.append(nn.Conv2d(out_channels, out_channels, kernel_size=kernel_size, padding=padding))
      layers.append(nn.BatchNorm2d(out_channels))
      layers.append(nn.ReLU(inplace=True))

    # Last Layer
    layers.append(nn.Conv2d(out_channels, in_channels, kernel_size=kernel_size, padding=padding))

    self.dncnn = nn.Sequential(*layers)
    self._initialize_weights()

  # Weight Initialization
  def _initialize_weights(self):
      for m in self.modules():
          if isinstance(m, nn.Conv2d):
              nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
          elif isinstance(m, nn.BatchNorm2d):
              nn.init.constant_(m.weight, 1)
              nn.init.constant_(m.bias, 0)

  # Residual Learning 노이즈만 출력
  def forward(self, x):
    return self.dncnn(x)

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
model = DnCNN(in_channels=config.in_channels, out_channels=config.out_channels, kernel_size=config.kernel_size, depth=config.num_layers).to(device)
summary(model, (128, config.in_channels, config.patch_size, config.patch_size), device=device)
# 왜 config.patch_size?
# 왜냐하면 입력을 patch로 crop해서 입력하기 때문에 patch size x patch size 이미지가 입력이 된다.
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DnCNN                                    [128, 3, 50, 50]          --
# ├─Sequential: 1-1                        [128, 3, 50, 50]          --
# │    └─Conv2d: 2-1                       [128, 64, 50, 50]         1,792
# │    └─ReLU: 2-2                         [128, 64, 50, 50]         --
# │    └─Conv2d: 2-3                       [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-4                  [128, 64, 50, 50]         128
# │    └─ReLU: 2-5                         [128, 64, 50, 50]         --
# │    └─Conv2d: 2-6                       [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-7                  [128, 64, 50, 50]         128
# │    └─ReLU: 2-8                         [128, 64, 50, 50]         --
# │    └─Conv2d: 2-9                       [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-10                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-11                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-12                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-13                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-14                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-15                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-16                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-17                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-18                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-19                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-20                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-21                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-22                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-23                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-24                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-25                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-26                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-27                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-28                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-29                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-30                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-31                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-32                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-33                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-34                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-35                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-36                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-37                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-38                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-39                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-40                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-41                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-42                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-43                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-44                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-45                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-46                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-47                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-48                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-49                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-50                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-51                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-52                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-53                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-54                      [128, 64, 50, 50]         36,928
# │    └─BatchNorm2d: 2-55                 [128, 64, 50, 50]         128
# │    └─ReLU: 2-56                        [128, 64, 50, 50]         --
# │    └─Conv2d: 2-57                      [128, 3, 50, 50]          1,731
# ==========================================================================================
# Total params: 670,531
# Trainable params: 670,531
# Non-trainable params: 0
# Total mult-adds (G): 213.83
# ==========================================================================================
# Input size (MB): 3.84
# Forward/backward pass size (MB): 6069.76
# Params size (MB): 2.68
# Estimated Total Size (MB): 6076.28
# ==========================================================================================

# %%
def current_psnr(mse):
  if mse ==0:
    return float('inf')
  return 10*np.log10(1.0/mse)

# minibatch의 손실 및 psnr
def loss_minibatch(model, noisy, clean, loss_func, opt=None):
  noise_pred = model(noisy)
  noisy_true = noisy-clean
  loss_b = loss_func(noise_pred, noisy_true)

  with torch.no_grad():
    denoised=noisy-noise_pred
    mse=nn.functional.mse_loss(denoised, clean).item()
    psnr_b = current_psnr(mse)

  if opt is not None:
    opt.zero_grad()
    loss_b.backward()
    opt.step()

  return loss_b.item(), psnr_b

# epoch 전체의 손실 및 psnr
def loss_epoch(model, dataloader, loss_func, opt=None):
  running_loss = 0.0
  running_psnr = 0.0
  total = 0

  # Training mode or Evaluation mode
  if opt is not None:
      model.train()
  else:
      model.eval()

  for noisy, clean in dataloader:
    noisy, clean = noisy.to(device), clean.to(device)

    if opt is None:
          with torch.no_grad():
              loss_b, psnr_b = loss_minibatch(model, noisy, clean, loss_func, opt)
    else:
          loss_b, psnr_b = loss_minibatch(model, noisy, clean, loss_func, opt)

    batch_size = noisy.size(0)
    running_loss += loss_b * batch_size
    running_psnr += psnr_b * batch_size
    total += batch_size

  epoch_loss = running_loss / total
  epoch_psnr = running_psnr / total

  return epoch_loss, epoch_psnr

# %%
# 데이터셋 생성
print('Train images :', len(train_list))
print('Validation images :',len(val_list))

train_dataset = DnCNN_Dataset(
      root=config.train_data_root,
      file_list=train_list,
      patch_size=config.patch_size,
      is_train=True,
      sigma_range=config.sigma_range,
      patches_per_image=config.patches_per_image,
)
val_dataset = DnCNN_Dataset(
      root=config.val_data_root,
      file_list=val_list,
      patch_size=config.patch_size,
      is_train=False,
      sigma_range=config.sigma_range,
)

train_loader = DataLoader(
      train_dataset,
      batch_size=config.batch_size,
      shuffle=True,
)

val_loader = DataLoader(
      val_dataset,
      batch_size=config.batch_size,
      shuffle=False,
)
# Out:
# Train images : 400
# Validation images : 32

# %%
import copy
import time

loss_func = nn.MSELoss()
model_opt = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(model_opt, gamma=0.862)

def train(model, params):
    loss_func = params['loss_func']
    num_epochs = params['num_epochs']
    optimizer = params['optimizer']
    lr_scheduler = params['lr_scheduler']
    path2weights = params['path2weights']
    
    history = {
        'train_loss': [],
        'train_psnr': [],
        'val_loss': [],
        'val_psnr': [],
        'lr': []
    }
    
    best_val_psnr = 0.0
    start_time = time.time()
    
    for epoch in range(num_epochs):
        epoch_start = time.time()
        current_lr = optimizer.param_groups[0]['lr']
        
        print(f'\n{"="*70}')
        print(f'Epoch [{epoch+1}/{num_epochs}] - LR: {current_lr:.6f}')
        print(f'{"="*70}')
        
        # Training
        print('Training...')
        train_loss, train_psnr = loss_epoch(model, train_loader, loss_func, optimizer)
        
        # Validation
        print('Validating...')
        val_loss, val_psnr = loss_epoch(model, val_loader, loss_func, None)
        
        epoch_time = time.time() - epoch_start
        elapsed_time = time.time() - start_time
        
        # 결과 출력
        print(f'\nResults:')
        print(f'  Train - Loss: {train_loss:.6f}, PSNR: {train_psnr:.2f} dB')
        print(f'  Val   - Loss: {val_loss:.6f}, PSNR: {val_psnr:.2f} dB')
        print(f'  Epoch Time: {epoch_time:.1f}s')
        print(f'  Total Elapsed: {elapsed_time/60:.1f}min')
        
        # 예상 남은 시간
        avg_epoch_time = elapsed_time / (epoch + 1)
        remaining_time = avg_epoch_time * (num_epochs - epoch - 1)
        print(f'  Estimated Remaining: {remaining_time/60:.1f}min')
        
        # History 저장
        history['train_loss'].append(train_loss)
        history['train_psnr'].append(train_psnr)
        history['val_loss'].append(val_loss)
        history['val_psnr'].append(val_psnr)
        history['lr'].append(current_lr)
        
        lr_scheduler.step()
        
        if val_psnr > best_val_psnr:
            best_val_psnr = val_psnr
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print(f'  ✓ Best model saved! (PSNR: {val_psnr:.2f} dB)')
    
    model.load_state_dict(best_model_weights)
    
    total_time = time.time() - start_time
    print(f'\n{"="*70}')
    print(f'Training completed in {total_time/60:.1f} minutes')
    print(f'Best Val PSNR: {best_val_psnr:.2f} dB')
    print(f'{"="*70}')
    
    return history

# %%
def test(model: torch.nn.Module, params: dict) -> tuple[float, float]:
  test_dl = params['test_dl']
  loss_func = params['loss_func']
  path2weights = params['path2weights']

  # Load the best model weights
  model.load_state_dict(torch.load(path2weights))

  # Evaluate the model on the test dataset
  test_loss, test_psnr = loss_epoch(model, test_dl, loss_func, None)

  print('Test Results')
  print('='*70)
  print(f'Test Loss: {test_loss:.6f}')
  print(f'Test PSNR: {test_psnr:.2f} dB')

  return test_loss, test_psnr

# %%
params_train = {
    'num_epochs': config.num_epochs,
    'batch_size': config.batch_size,
    'loss_func': loss_func,
    'lr_scheduler': lr_scheduler,
    'optimizer': model_opt,
    'path2weights': '/Users/shinminseo/Documents/학교자료&공부/딥러닝/DnCNN/DnCNN-C(base).pth'
}

# %%
history = train(model, params_train)
# Out:
# ======================================================================
# Epoch [1/50] - LR: 0.001000
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.148483, PSNR: 16.62 dB
#   Val   - Loss: 0.015332, PSNR: 18.14 dB
#   Epoch Time: 510.7s
#   Total Elapsed: 8.5min
#   Estimated Remaining: 417.1min
#   ✓ Best model saved! (PSNR: 18.14 dB)
#
# ======================================================================
# Epoch [2/50] - LR: 0.000862
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.015971, PSNR: 17.98 dB
#   Val   - Loss: 0.015183, PSNR: 18.19 dB
#   Epoch Time: 508.7s
#   Total Elapsed: 17.0min
#   Estimated Remaining: 407.8min
#   ✓ Best model saved! (PSNR: 18.19 dB)
#
# ======================================================================
# Epoch [3/50] - LR: 0.000743
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.015542, PSNR: 18.10 dB
#   Val   - Loss: 0.014309, PSNR: 18.44 dB
#   Epoch Time: 508.3s
#   Total Elapsed: 25.5min
#   Estimated Remaining: 398.9min
#   ✓ Best model saved! (PSNR: 18.44 dB)
#
# ======================================================================
# Epoch [4/50] - LR: 0.000641
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.014297, PSNR: 18.46 dB
#   Val   - Loss: 0.012833, PSNR: 18.92 dB
#   Epoch Time: 508.4s
#   Total Elapsed: 33.9min
#   Estimated Remaining: 390.3min
#   ✓ Best model saved! (PSNR: 18.92 dB)
#
# ======================================================================
# Epoch [5/50] - LR: 0.000552
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.012472, PSNR: 19.06 dB
#   Val   - Loss: 0.010674, PSNR: 19.72 dB
#   Epoch Time: 511.1s
#   Total Elapsed: 42.5min
#   Estimated Remaining: 382.1min
#   ✓ Best model saved! (PSNR: 19.72 dB)
#
# ======================================================================
# Epoch [6/50] - LR: 0.000476
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.010143, PSNR: 19.96 dB
#   Val   - Loss: 0.008579, PSNR: 20.67 dB
#   Epoch Time: 510.4s
#   Total Elapsed: 51.0min
#   Estimated Remaining: 373.7min
#   ✓ Best model saved! (PSNR: 20.67 dB)
#
# ======================================================================
# Epoch [7/50] - LR: 0.000410
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.008098, PSNR: 20.94 dB
#   Val   - Loss: 0.006456, PSNR: 21.90 dB
#   Epoch Time: 510.8s
#   Total Elapsed: 59.5min
#   Estimated Remaining: 365.4min
#   ✓ Best model saved! (PSNR: 21.90 dB)
#
# ======================================================================
# Epoch [8/50] - LR: 0.000354
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.006158, PSNR: 22.13 dB
#   Val   - Loss: 0.004837, PSNR: 23.15 dB
#   Epoch Time: 508.0s
#   Total Elapsed: 67.9min
#   Estimated Remaining: 356.7min
#   ✓ Best model saved! (PSNR: 23.15 dB)
#
# ======================================================================
# Epoch [9/50] - LR: 0.000305
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.004939, PSNR: 23.08 dB
#   Val   - Loss: 0.004029, PSNR: 23.95 dB
#   Epoch Time: 506.6s
#   Total Elapsed: 76.4min
#   Estimated Remaining: 348.0min
#   ✓ Best model saved! (PSNR: 23.95 dB)
#
# ======================================================================
# Epoch [10/50] - LR: 0.000263
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.004268, PSNR: 23.71 dB
#   Val   - Loss: 0.003615, PSNR: 24.42 dB
#   Epoch Time: 504.1s
#   Total Elapsed: 84.8min
#   Estimated Remaining: 339.2min
#   ✓ Best model saved! (PSNR: 24.42 dB)
#
# ======================================================================
# Epoch [11/50] - LR: 0.000227
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.003822, PSNR: 24.19 dB
#   Val   - Loss: 0.003311, PSNR: 24.80 dB
#   Epoch Time: 508.4s
#   Total Elapsed: 93.3min
#   Estimated Remaining: 330.7min
#   ✓ Best model saved! (PSNR: 24.80 dB)
#
# ======================================================================
# Epoch [12/50] - LR: 0.000195
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.003530, PSNR: 24.54 dB
#   Val   - Loss: 0.003349, PSNR: 24.75 dB
#   Epoch Time: 505.1s
#   Total Elapsed: 101.7min
#   Estimated Remaining: 322.0min
#
# ======================================================================
# Epoch [13/50] - LR: 0.000168
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.003266, PSNR: 24.88 dB
#   Val   - Loss: 0.003010, PSNR: 25.21 dB
#   Epoch Time: 505.0s
#   Total Elapsed: 110.1min
#   Estimated Remaining: 313.4min
#   ✓ Best model saved! (PSNR: 25.21 dB)
#
# ======================================================================
# Epoch [14/50] - LR: 0.000145
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.003050, PSNR: 25.17 dB
#   Val   - Loss: 0.002851, PSNR: 25.45 dB
#   Epoch Time: 507.4s
#   Total Elapsed: 118.6min
#   Estimated Remaining: 304.9min
#   ✓ Best model saved! (PSNR: 25.45 dB)
#
# ======================================================================
# Epoch [15/50] - LR: 0.000125
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002816, PSNR: 25.52 dB
#   Val   - Loss: 0.002672, PSNR: 25.73 dB
#   Epoch Time: 509.3s
#   Total Elapsed: 127.0min
#   Estimated Remaining: 296.4min
#   ✓ Best model saved! (PSNR: 25.73 dB)
#
# ======================================================================
# Epoch [16/50] - LR: 0.000108
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002664, PSNR: 25.76 dB
#   Val   - Loss: 0.002582, PSNR: 25.88 dB
#   Epoch Time: 513.5s
#   Total Elapsed: 135.6min
#   Estimated Remaining: 288.2min
#   ✓ Best model saved! (PSNR: 25.88 dB)
#
# ======================================================================
# Epoch [17/50] - LR: 0.000093
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002522, PSNR: 26.00 dB
#   Val   - Loss: 0.002378, PSNR: 26.24 dB
#   Epoch Time: 511.2s
#   Total Elapsed: 144.1min
#   Estimated Remaining: 279.8min
#   ✓ Best model saved! (PSNR: 26.24 dB)
#
# ======================================================================
# Epoch [18/50] - LR: 0.000080
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002379, PSNR: 26.25 dB
#   Val   - Loss: 0.002282, PSNR: 26.42 dB
#   Epoch Time: 514.3s
#   Total Elapsed: 152.7min
#   Estimated Remaining: 271.5min
#   ✓ Best model saved! (PSNR: 26.42 dB)
#
# ======================================================================
# Epoch [19/50] - LR: 0.000069
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002251, PSNR: 26.49 dB
#   Val   - Loss: 0.002205, PSNR: 26.57 dB
#   Epoch Time: 505.7s
#   Total Elapsed: 161.1min
#   Estimated Remaining: 262.9min
#   ✓ Best model saved! (PSNR: 26.57 dB)
#
# ======================================================================
# Epoch [20/50] - LR: 0.000060
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002167, PSNR: 26.66 dB
#   Val   - Loss: 0.002308, PSNR: 26.37 dB
#   Epoch Time: 507.3s
#   Total Elapsed: 169.6min
#   Estimated Remaining: 254.4min
#
# ======================================================================
# Epoch [21/50] - LR: 0.000051
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002084, PSNR: 26.83 dB
#   Val   - Loss: 0.002055, PSNR: 26.87 dB
#   Epoch Time: 507.5s
#   Total Elapsed: 178.0min
#   Estimated Remaining: 245.9min
#   ✓ Best model saved! (PSNR: 26.87 dB)
#
# ======================================================================
# Epoch [22/50] - LR: 0.000044
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.002024, PSNR: 26.95 dB
#   Val   - Loss: 0.002018, PSNR: 26.95 dB
#   Epoch Time: 508.7s
#   Total Elapsed: 186.5min
#   Estimated Remaining: 237.4min
#   ✓ Best model saved! (PSNR: 26.95 dB)
#
# ======================================================================
# Epoch [23/50] - LR: 0.000038
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001972, PSNR: 27.07 dB
#   Val   - Loss: 0.002169, PSNR: 26.64 dB
#   Epoch Time: 508.9s
#   Total Elapsed: 195.0min
#   Estimated Remaining: 228.9min
#
# ======================================================================
# Epoch [24/50] - LR: 0.000033
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001918, PSNR: 27.19 dB
#   Val   - Loss: 0.001938, PSNR: 27.13 dB
#   Epoch Time: 509.1s
#   Total Elapsed: 203.5min
#   Estimated Remaining: 220.4min
#   ✓ Best model saved! (PSNR: 27.13 dB)
#
# ======================================================================
# Epoch [25/50] - LR: 0.000028
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001888, PSNR: 27.25 dB
#   Val   - Loss: 0.001942, PSNR: 27.12 dB
#   Epoch Time: 509.4s
#   Total Elapsed: 212.0min
#   Estimated Remaining: 212.0min
#
# ======================================================================
# Epoch [26/50] - LR: 0.000024
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001852, PSNR: 27.34 dB
#   Val   - Loss: 0.001887, PSNR: 27.24 dB
#   Epoch Time: 507.9s
#   Total Elapsed: 220.4min
#   Estimated Remaining: 203.5min
#   ✓ Best model saved! (PSNR: 27.24 dB)
#
# ======================================================================
# Epoch [27/50] - LR: 0.000021
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001838, PSNR: 27.37 dB
#   Val   - Loss: 0.001857, PSNR: 27.31 dB
#   Epoch Time: 508.2s
#   Total Elapsed: 228.9min
#   Estimated Remaining: 195.0min
#   ✓ Best model saved! (PSNR: 27.31 dB)
#
# ======================================================================
# Epoch [28/50] - LR: 0.000018
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001811, PSNR: 27.43 dB
#   Val   - Loss: 0.001858, PSNR: 27.31 dB
#   Epoch Time: 509.1s
#   Total Elapsed: 237.4min
#   Estimated Remaining: 186.5min
#
# ======================================================================
# Epoch [29/50] - LR: 0.000016
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001803, PSNR: 27.45 dB
#   Val   - Loss: 0.001823, PSNR: 27.39 dB
#   Epoch Time: 511.0s
#   Total Elapsed: 245.9min
#   Estimated Remaining: 178.1min
#   ✓ Best model saved! (PSNR: 27.39 dB)
#
# ======================================================================
# Epoch [30/50] - LR: 0.000013
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001776, PSNR: 27.52 dB
#   Val   - Loss: 0.001835, PSNR: 27.36 dB
#   Epoch Time: 512.4s
#   Total Elapsed: 254.5min
#   Estimated Remaining: 169.6min
#
# ======================================================================
# Epoch [31/50] - LR: 0.000012
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001765, PSNR: 27.55 dB
#   Val   - Loss: 0.001818, PSNR: 27.41 dB
#   Epoch Time: 513.3s
#   Total Elapsed: 263.0min
#   Estimated Remaining: 161.2min
#   ✓ Best model saved! (PSNR: 27.41 dB)
#
# ======================================================================
# Epoch [32/50] - LR: 0.000010
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001763, PSNR: 27.55 dB
#   Val   - Loss: 0.001810, PSNR: 27.42 dB
#   Epoch Time: 512.2s
#   Total Elapsed: 271.5min
#   Estimated Remaining: 152.7min
#   ✓ Best model saved! (PSNR: 27.42 dB)
#
# ======================================================================
# Epoch [33/50] - LR: 0.000009
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001750, PSNR: 27.58 dB
#   Val   - Loss: 0.001820, PSNR: 27.40 dB
#   Epoch Time: 513.5s
#   Total Elapsed: 280.1min
#   Estimated Remaining: 144.3min
#
# ======================================================================
# Epoch [34/50] - LR: 0.000007
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001745, PSNR: 27.60 dB
#   Val   - Loss: 0.001814, PSNR: 27.41 dB
#   Epoch Time: 516.2s
#   Total Elapsed: 288.7min
#   Estimated Remaining: 135.9min
#
# ======================================================================
# Epoch [35/50] - LR: 0.000006
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001739, PSNR: 27.61 dB
#   Val   - Loss: 0.001810, PSNR: 27.42 dB
#   Epoch Time: 513.1s
#   Total Elapsed: 297.3min
#   Estimated Remaining: 127.4min
#   ✓ Best model saved! (PSNR: 27.42 dB)
#
# ======================================================================
# Epoch [36/50] - LR: 0.000006
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001734, PSNR: 27.62 dB
#   Val   - Loss: 0.001805, PSNR: 27.44 dB
#   Epoch Time: 512.3s
#   Total Elapsed: 305.8min
#   Estimated Remaining: 118.9min
#   ✓ Best model saved! (PSNR: 27.44 dB)
#
# ======================================================================
# Epoch [37/50] - LR: 0.000005
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001730, PSNR: 27.63 dB
#   Val   - Loss: 0.001785, PSNR: 27.48 dB
#   Epoch Time: 509.8s
#   Total Elapsed: 314.3min
#   Estimated Remaining: 110.4min
#   ✓ Best model saved! (PSNR: 27.48 dB)
#
# ======================================================================
# Epoch [38/50] - LR: 0.000004
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001721, PSNR: 27.66 dB
#   Val   - Loss: 0.001794, PSNR: 27.46 dB
#   Epoch Time: 512.2s
#   Total Elapsed: 322.8min
#   Estimated Remaining: 101.9min
#
# ======================================================================
# Epoch [39/50] - LR: 0.000004
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001715, PSNR: 27.67 dB
#   Val   - Loss: 0.001785, PSNR: 27.48 dB
#   Epoch Time: 518.1s
#   Total Elapsed: 331.5min
#   Estimated Remaining: 93.5min
#
# ======================================================================
# Epoch [40/50] - LR: 0.000003
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001703, PSNR: 27.70 dB
#   Val   - Loss: 0.001799, PSNR: 27.45 dB
#   Epoch Time: 507.4s
#   Total Elapsed: 339.9min
#   Estimated Remaining: 85.0min
#
# ======================================================================
# Epoch [41/50] - LR: 0.000003
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001714, PSNR: 27.67 dB
#   Val   - Loss: 0.001788, PSNR: 27.48 dB
#   Epoch Time: 506.1s
#   Total Elapsed: 348.4min
#   Estimated Remaining: 76.5min
#
# ======================================================================
# Epoch [42/50] - LR: 0.000002
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001688, PSNR: 27.74 dB
#   Val   - Loss: 0.001764, PSNR: 27.53 dB
#   Epoch Time: 506.7s
#   Total Elapsed: 356.8min
#   Estimated Remaining: 68.0min
#   ✓ Best model saved! (PSNR: 27.53 dB)
#
# ======================================================================
# Epoch [43/50] - LR: 0.000002
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001692, PSNR: 27.73 dB
#   Val   - Loss: 0.001774, PSNR: 27.51 dB
#   Epoch Time: 509.4s
#   Total Elapsed: 365.3min
#   Estimated Remaining: 59.5min
#
# ======================================================================
# Epoch [44/50] - LR: 0.000002
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001697, PSNR: 27.72 dB
#   Val   - Loss: 0.001774, PSNR: 27.51 dB
#   Epoch Time: 508.6s
#   Total Elapsed: 373.8min
#   Estimated Remaining: 51.0min
#
# ======================================================================
# Epoch [45/50] - LR: 0.000001
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001688, PSNR: 27.74 dB
#   Val   - Loss: 0.001770, PSNR: 27.52 dB
#   Epoch Time: 508.4s
#   Total Elapsed: 382.3min
#   Estimated Remaining: 42.5min
#
# ======================================================================
# Epoch [46/50] - LR: 0.000001
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001695, PSNR: 27.72 dB
#   Val   - Loss: 0.001763, PSNR: 27.54 dB
#   Epoch Time: 508.5s
#   Total Elapsed: 390.7min
#   Estimated Remaining: 34.0min
#   ✓ Best model saved! (PSNR: 27.54 dB)
#
# ======================================================================
# Epoch [47/50] - LR: 0.000001
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001684, PSNR: 27.75 dB
#   Val   - Loss: 0.001775, PSNR: 27.51 dB
#   Epoch Time: 513.1s
#   Total Elapsed: 399.3min
#   Estimated Remaining: 25.5min
#
# ======================================================================
# Epoch [48/50] - LR: 0.000001
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001691, PSNR: 27.73 dB
#   Val   - Loss: 0.001780, PSNR: 27.50 dB
#   Epoch Time: 513.1s
#   Total Elapsed: 407.8min
#   Estimated Remaining: 17.0min
#
# ======================================================================
# Epoch [49/50] - LR: 0.000001
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001684, PSNR: 27.75 dB
#   Val   - Loss: 0.001773, PSNR: 27.51 dB
#   Epoch Time: 514.1s
#   Total Elapsed: 416.4min
#   Estimated Remaining: 8.5min
#
# ======================================================================
# Epoch [50/50] - LR: 0.000001
# ======================================================================
# Training...
# Validating...
#
# Results:
#   Train - Loss: 0.001682, PSNR: 27.76 dB
#   Val   - Loss: 0.001767, PSNR: 27.53 dB
#   Epoch Time: 514.8s
#   Total Elapsed: 425.0min
#   Estimated Remaining: 0.0min
#
# ======================================================================
# Training completed in 425.0 minutes
# Best Val PSNR: 27.54 dB
# ======================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# 1. Loss & PSNR 그래프
# ============================================================================
def plot_results(history):
    """Loss와 PSNR 그래프 그리기"""
    epochs = range(1, len(history['train_loss']) + 1)
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Loss
    axes[0].plot(epochs, history['train_loss'], 'b-', label='Train', linewidth=2)
    axes[0].plot(epochs, history['val_loss'], 'r-', label='Val', linewidth=2)
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss', fontsize=14, fontweight='bold')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # PSNR
    axes[1].plot(epochs, history['train_psnr'], 'b-', label='Train', linewidth=2)
    axes[1].plot(epochs, history['val_psnr'], 'r-', label='Val', linewidth=2)
    best_epoch = np.argmax(history['val_psnr']) + 1
    best_psnr = max(history['val_psnr'])
    axes[1].axvline(x=best_epoch, color='r', linestyle='--', alpha=0.5)
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('PSNR (dB)', fontsize=12)
    axes[1].set_title(f'PSNR (Best: {best_psnr:.2f}dB at epoch {best_epoch})', 
                     fontsize=14, fontweight='bold')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


# ============================================================================
# 2. Denoising 결과 시각화
# ============================================================================
def show_denoising_results(model, dataloader, device, num_samples=5):
    """
    Noisy → Denoised 결과 이미지 비교
    """
    model.eval()
    
    # 샘플 가져오기
    noisy_list = []
    clean_list = []
    denoised_list = []
    
    with torch.no_grad():
        for noisy, clean in dataloader:
            noisy = noisy.to(device)
            clean = clean.to(device)
            
            # Denoising
            noise_pred = model(noisy)
            denoised = noisy - noise_pred
            
            noisy_list.append(noisy.cpu())
            clean_list.append(clean.cpu())
            denoised_list.append(denoised.cpu())
            
            if len(noisy_list) * noisy.size(0) >= num_samples:
                break
    
    # Tensor 합치기
    noisy_all = torch.cat(noisy_list, dim=0)[:num_samples]
    clean_all = torch.cat(clean_list, dim=0)[:num_samples]
    denoised_all = torch.cat(denoised_list, dim=0)[:num_samples]
    
    # 시각화
    fig, axes = plt.subplots(num_samples, 3, figsize=(12, num_samples*3))
    
    if num_samples == 1:
        axes = axes.reshape(1, -1)
    
    for i in range(num_samples):
        # Clip
        noisy_img = np.clip(noisy_all[i].permute(1,2,0).numpy(), 0, 1)
        clean_img = np.clip(clean_all[i].permute(1,2,0).numpy(), 0, 1)
        denoised_img = np.clip(denoised_all[i].permute(1,2,0).numpy(), 0, 1)
        
        # PSNR 계산
        mse = np.mean((denoised_img - clean_img) ** 2)
        psnr = 10 * np.log10(1.0 / mse) if mse > 0 else float('inf')
        
        # Noisy
        axes[i, 0].imshow(noisy_img)
        axes[i, 0].set_title('Noisy', fontsize=12)
        axes[i, 0].axis('off')
        
        # Denoised
        axes[i, 1].imshow(denoised_img)
        axes[i, 1].set_title(f'Denoised (PSNR: {psnr:.2f}dB)', fontsize=12)
        axes[i, 1].axis('off')
        
        # Clean (Ground Truth)
        axes[i, 2].imshow(clean_img)
        axes[i, 2].set_title('Clean (GT)', fontsize=12)
        axes[i, 2].axis('off')
    
    plt.tight_layout()
    plt.show()


# ============================================================================
# 실행
# ============================================================================

# 1. Loss & PSNR 그래프
plot_results(history)

# 2. Denoising 결과 (validation set에서 5개)
print('\nDenoising Results:')
show_denoising_results(model, val_loader, device, num_samples=5)

# 3. Test set 결과도 보고 싶다면
# show_denoising_results(model, test_loader, device, num_samples=5)
# Out:
# Denoising Results:
